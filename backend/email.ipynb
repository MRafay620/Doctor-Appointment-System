# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient
from bson import ObjectId

# MongoDB connection
def get_mongo_client():
    client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
    return client

# Fetch booking details along with user and doctor details
def get_booking_details(booking_id):
    client = get_mongo_client()
    db = client.your_database_name  # Replace with your actual database name
    booking = db.bookings.find_one({"_id": ObjectId(booking_id)})
    
    if booking:
        doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
        user = db.users.find_one({"_id": ObjectId(booking['user'])})
        booking['doctor_details'] = doctor
        booking['user_details'] = user
    
    client.close()
    return booking

# Send email function
def send_email(subject, to_email, body):
    from_email = "ahmadhassan8598@gmail.com"  # Replace with your email
    from_password = "ahmadhassan"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Main function to handle booking and email notifications
def handle_booking_email(booking_id):
    booking = get_booking_details(booking_id)
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email(user_subject, user_email, user_body)

        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email(doctor_subject, doctor_email, doctor_body)
    else:
        print(f"No booking found with ID: {booking_id}")

# Example usage
if __name__ == "__main__":
    booking_id = "6658518e2fa08c7c59b2b96c"  # Replace with actual booking ID
    handle_booking_email(booking_id)
# Out:
# No booking found with ID: 6658518e2fa08c7c59b2b96c

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient

# MongoDB connection
def get_mongo_client():
    client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
    return client

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    db = client.your_database_name  # Replace with your actual database name
    
    booking = db.bookings.find().sort("createdAt", -1).limit(1)[0]
    
    if booking:
        doctor = db.doctors.find_one({"_id": booking['doctor']})
        user = db.users.find_one({"_id": booking['user']})
        booking['doctor_details'] = doctor
        booking['user_details'] = user
    
    client.close()
    return booking

# Send email function
def send_email(subject, to_email, body):
    from_email = "ahmadhassan8598@gmail.com"  # Replace with your email
    from_password = "ahmadhassan"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email(user_subject, user_email, user_body)

        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email(doctor_subject, doctor_email, doctor_body)
    else:
        print(f"No recent bookings found.")

# Example usage
if __name__ == "__main__":
    handle_booking_email()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 82
#      80 # Example usage
#      81 if __name__ == "__main__":
# ---> 82     handle_booking_email()
#
# Cell In[6], line 53, in handle_booking_email()
#      52 def handle_booking_email():
# ---> 53     booking = get_most_recent_booking()
#      55     if booking:
#      56         user_email = booking['user_details']['email']
#
# Cell In[6], line 16, in get_most_recent_booking()
#      13 client = get_mongo_client()
#      14 db = client.your_database_name  # Replace with your actual database name
# ---> 16 booking = db.bookings.find().sort("createdAt", -1).limit(1)[0]
#      18 if booking:
#      19     doctor = db.doctors.find_one({"_id": booking['doctor']})
#
# File c:\Users\Muhammad Rafay\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\cursor.py:757, in Cursor.__getitem__(self, index)
# ...

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient

# MongoDB connection
def get_mongo_client():
    client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
    return client

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    db = client.your_database_name  # Replace with your actual database name
    
    cursor = db.bookings.find().sort("createdAt", -1).limit(1)
    booking = None

    if cursor.count() > 0:
        booking = cursor[0]
        if booking:
            doctor = db.doctors.find_one({"_id": booking['doctor']})
            user = db.users.find_one({"_id": booking['user']})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
    
    client.close()
    return booking

# Send email function
def send_email(subject, to_email, body):
    from_email = "ahmadhassan8598@gmail.com"  # Replace with your email
    from_password = "ahmadhassan"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email(user_subject, user_email, user_body)

        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email(doctor_subject, doctor_email, doctor_body)
    else:
        print("No recent bookings found.")

# Example usage
if __name__ == "__main__":
    handle_booking_email()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 85
#      83 # Example usage
#      84 if __name__ == "__main__":
# ---> 85     handle_booking_email()
#
# Cell In[7], line 56, in handle_booking_email()
#      55 def handle_booking_email():
# ---> 56     booking = get_most_recent_booking()
#      58     if booking:
#      59         user_email = booking['user_details']['email']
#
# Cell In[7], line 19, in get_most_recent_booking()
#      16 cursor = db.bookings.find().sort("createdAt", -1).limit(1)
#      17 booking = None
# ---> 19 if cursor.count() > 0:
#      20     booking = cursor[0]
#      21     if booking:
#
# AttributeError: 'Cursor' object has no attribute 'count'

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient

# MongoDB connection
def get_mongo_client():
    client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
    return client

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    db = client.doctorbackend  # Replace with your actual database name
    
    cursor = db.bookings.find().sort("createdAt", -1).limit(1)
    booking = None

    # Check if the cursor has any results
    for doc in cursor:
        booking = doc

    if booking:
        doctor = db.doctors.find_one({"_id": booking['doctor']})
        user = db.users.find_one({"_id": booking['user']})
        booking['doctor_details'] = doctor
        booking['user_details'] = user
    
    client.close()
    return booking

# Send email function
def send_email(subject, to_email, body):
    from_email = "ahmadhassan8598@gmail.com"  # Replace with your email
    from_password = "ahmadhassan"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email(user_subject, user_email, user_body)

        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email(doctor_subject, doctor_email, doctor_body)
    else:
        print("No recent bookings found.")

# Example usage
if __name__ == "__main__":
    handle_booking_email()
# Out:
# No recent bookings found.

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": booking['doctor']})
            user = db.users.find_one({"_id": booking['user']})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Send email function
def send_email(subject, to_email, body):
    from_email = "ahmadhassan8598@gmail.com"  # Replace with your email
    from_password = "ahmadhassan"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email(user_subject, user_email, user_body)

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email(doctor_subject, doctor_email, doctor_body)
    else:
        print("No recent bookings found.")

# Example usage
if __name__ == "__main__":
    handle_booking_email()
# Out:
# MongoDB connection successful
# No booking found
# No recent bookings found.

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": booking['doctor']})
            user = db.users.find_one({"_id": booking['user']})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Send email function
def send_email(subject, to_email, body):
    from_email = "ahmadhassan8598@gmail.com"  # Replace with your email
    from_password = "ahmadhassan"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email(user_subject, user_email, user_body)

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email(doctor_subject, doctor_email, doctor_body)
    else:
        print("No recent bookings found.")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# MongoDB connection successful
# No booking found
# No recent bookings found.

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient
from bson import ObjectId

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Send email function
def send_email(subject, to_email, body):
    from_email = "ahmadhassan8598@gmail.com"  # Replace with your email
    from_password = "ahmadhassan"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email(user_subject, user_email, user_body)

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email(doctor_subject, doctor_email, doctor_body)
    else:
        print("No recent bookings found.")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# MongoDB connection successful
# No booking found
# No recent bookings found.

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient
from bson import ObjectId

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))  # Explicitly print the createdAt field
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Send email function
def send_email(subject, to_email, body):
    from_email = "ahmadhassan8598@gmail.com"  # Replace with your email
    from_password = "ahmadhassan"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email(user_subject, user_email, user_body)

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email(doctor_subject, doctor_email, doctor_body)
    else:
        print("No recent bookings found.")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# MongoDB connection successful
# No booking found
# No recent bookings found.

# %%
import os
from pymongo import MongoClient
from sendgrid import SendGridAPIClient
from sendgrid.helpers.mail import Mail

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": booking['doctor']})
            user = db.users.find_one({"_id": booking['user']})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Send email using SendGrid
def send_email_via_sendgrid(to_email, subject, body):
    message = Mail(
        from_email='your_email@example.com',  # Replace with your SendGrid verified sender email
        to_emails=to_email,
        subject=subject,
        plain_text_content=body)
    
    try:
        sg = SendGridAPIClient(os.environ.get('SENDGRID_API_KEY'))
        response = sg.send(message)
        print(response.status_code)
        print(response.body)
        print(response.headers)
    except Exception as e:
        print(f"Failed to send email: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email_via_sendgrid(user_email, user_subject, user_body)

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email_via_sendgrid(doctor_email, doctor_subject, doctor_body)
    else:
        print("No recent bookings found.")

# Example usage
if __name__ == "__main__":
    handle_booking_email()

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient
from bson import ObjectId

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))  # Explicitly print the createdAt field
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Send email function
def send_email(subject, to_email, body):
    from_email = "ahmadhassan8598@gmail.com"  # Replace with your email
    from_password = "ahmadhassan"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email(user_subject, user_email, user_body)

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email(doctor_subject, doctor_email, doctor_body)
    else:
        print("No recent bookings found.")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# MongoDB connection successful
# No booking found
# No recent bookings found.

# %%
pip install yagmail
# Out:
# ...
#    ---------------------------------------- 0.0/385.7 kB ? eta -:--:--
#    --- ------------------------------------ 30.7/385.7 kB 1.3 MB/s eta 0:00:01
#    ------ --------------------------------- 61.4/385.7 kB 1.1 MB/s eta 0:00:01
#    ------ --------------------------------- 61.4/385.7 kB 1.1 MB/s eta 0:00:01
#    ------------ ------------------------- 122.9/385.7 kB 722.1 kB/s eta 0:00:01
#    ------------------- ------------------ 194.6/385.7 kB 980.4 kB/s eta 0:00:01
#    ------------------- ------------------ 194.6/385.7 kB 980.4 kB/s eta 0:00:01
#    --------------------------- ---------- 276.5/385.7 kB 896.4 kB/s eta 0:00:01
#    -------------------------------- ----- 327.7/385.7 kB 967.8 kB/s eta 0:00:01
#    -------------------------------- ----- 327.7/385.7 kB 967.8 kB/s eta 0:00:01
#    -------------------------------------  378.9/385.7 kB 841.6 kB/s eta 0:00:01
#    -------------------------------------- 385.7/385.7 kB 828.9 kB/s eta 0:00:00
# ...

# %%
import yagmail
from pymongo import MongoClient
from bson import ObjectId

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Send email function using yagmail
def send_email_via_yagmail(to_email, subject, body):
    yag = yagmail.SMTP('ahmadhassan8598@gmail.com', 'ahmadhassan')
    try:
        yag.send(to=to_email, subject=subject, contents=body)
        print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email: {e}")

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        send_email_via_yagmail(user_email, user_subject, user_body)

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        send_email_via_yagmail(doctor_email, doctor_subject, doctor_body)
    else:
        print("No recent bookings found.")

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Replace with your actual database name
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))  # Explicitly print the createdAt field
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# MongoDB connection successful
# No booking found
# No recent bookings found.

# %%
from pymongo import MongoClient
from bson import ObjectId

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
            print("Booking details with doctor and user info:", booking)
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Example usage
if __name__ == "__main__":
    # Fetch and print the most recent booking
    booking = get_most_recent_booking()
    if booking:
        print("Most recent booking details:", booking)
# Out:
# MongoDB connection successful
# Booking found: {'_id': ObjectId('667e6ea25679fc87a77981cd'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'pending', 'isPaid': True, 'createdAt': datetime.datetime(2024, 6, 28, 8, 4, 50, 374000), 'updatedAt': datetime.datetime(2024, 6, 28, 8, 4, 50, 374000), '__v': 0}
# ...

# %%
from pymongo import MongoClient
from bson import ObjectId

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))  # Explicitly print the createdAt field
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# {'_id': ObjectId('6658518e2fa08c7c59b2b96c'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), 'updatedAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), '__v': 0}
# createdAt: 2024-05-30 10:14:38.360000
# {'_id': ObjectId('667e50ba5679fc87a7798187'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), 'updatedAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), '__v': 0}
# createdAt: 2024-06-28 05:57:14.699000
# ...

# %%
import yagmail

def send_email_via_yagmail(to_email, subject, body):
    yag = yagmail.SMTP('doctorbackend9@gmail.com', 'Qwertybgh786')  # Replace with your email and password
    try:
        yag.send(to=to_email, subject=subject, contents=body)
        print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email: {e}")

# Example usage
if __name__ == "__main__":
    send_email_via_yagmail('muhammadrafay620@icloud.com', 'Test Subject', 'Test Body')
# Out:
# Failed to send email: (534, b'5.7.9 Application-specific password required. For more information, go to\n5.7.9  https://support.google.com/mail/?p=InvalidSecondFactor 5b1f17b1804b1-4256f55c4b5sm11210865e9.43 - gsmtp')

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient
from bson import ObjectId

# Email service class
class EmailService:
    def __init__(self):
        pass

    def send_email(self, sender_email, sender_passwd, receiver_email, subject, body):
        smtp = 'smtp.gmail.com'
        smtp_port = 587
        session = smtplib.SMTP(smtp, smtp_port)
        session.starttls()
        session.login(sender_email, sender_passwd)
        
        # Setup the MIME
        message = MIMEMultipart()
        message['From'] = sender_email
        message['To'] = receiver_email
        message['Subject'] = subject

        # Add body to email
        message.attach(MIMEText(body, 'plain'))

        session.sendmail(sender_email, receiver_email, message.as_string())
        session.quit()
        print(f"Email sent to {receiver_email}")

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
            print("Booking details with doctor and user info:", booking)
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        email_service = EmailService()

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        email_service.send_email(
            sender_email='your_email@gmail.com',  # Replace with your email
            sender_passwd='your_app_password',  # Replace with your app password
            receiver_email=user_email,
            subject=user_subject,
            body=user_body
        )

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        email_service.send_email(
            sender_email='your_email@gmail.com',  # Replace with your email
            sender_passwd='your_app_password',  # Replace with your app password
            receiver_email=doctor_email,
            subject=doctor_subject,
            body=doctor_body
        )
    else:
        print("No recent bookings found.")

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))  # Explicitly print the createdAt field
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# {'_id': ObjectId('6658518e2fa08c7c59b2b96c'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), 'updatedAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), '__v': 0}
# createdAt: 2024-05-30 10:14:38.360000
# {'_id': ObjectId('667e50ba5679fc87a7798187'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), 'updatedAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), '__v': 0}
# createdAt: 2024-06-28 05:57:14.699000
# ...

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient
from bson import ObjectId

# Email service class
class EmailService:
    def __init__(self):
        pass

    def send_email(self, sender_email, sender_passwd, receiver_email, subject, body):
        smtp = 'smtp.gmail.com'
        smtp_port = 587
        session = smtplib.SMTP(smtp, smtp_port)
        session.starttls()
        session.login(sender_email, sender_passwd)
        
        # Setup the MIME
        message = MIMEMultipart()
        message['From'] = sender_email
        message['To'] = receiver_email
        message['Subject'] = subject

        # Add body to email
        message.attach(MIMEText(body, 'plain'))

        session.sendmail(sender_email, receiver_email, message.as_string())
        session.quit()
        print(f"Email sent to {receiver_email}")

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
            print("Booking details with doctor and user info:", booking)
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        email_service = EmailService()

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        email_service.send_email(
            sender_email='your_email@gmail.com',  # Replace with your email
            sender_passwd='your_app_password',  # Replace with your app password
            receiver_email=user_email,
            subject=user_subject,
            body=user_body
        )

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        email_service.send_email(
            sender_email='doctorbackend9@gmail.com',  # Replace with your email
            sender_passwd='Qwertybgh786',  # Replace with your app password
            receiver_email=doctor_email,
            subject=doctor_subject,
            body=doctor_body
        )
    else:
        print("No recent bookings found.")

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.doctorbackend  # Use the 'test' database
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))  # Explicitly print the createdAt field
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# MongoDB connection successful
# Booking found: {'_id': ObjectId('667e6ea25679fc87a77981cd'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'pending', 'isPaid': True, 'createdAt': datetime.datetime(2024, 6, 28, 8, 4, 50, 374000), 'updatedAt': datetime.datetime(2024, 6, 28, 8, 4, 50, 374000), '__v': 0}
# ...

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient
from bson import ObjectId

# Email service class
class EmailService:
    def __init__(self):
        pass

    def send_email(self, sender_email, sender_passwd, receiver_email, subject, body):
        smtp = 'smtp.gmail.com'
        smtp_port = 587
        session = smtplib.SMTP(smtp, smtp_port)
        session.starttls()
        session.login(sender_email, sender_passwd)
        
        # Setup the MIME
        message = MIMEMultipart()
        message['From'] = sender_email
        message['To'] = receiver_email
        message['Subject'] = subject

        # Add body to email
        message.attach(MIMEText(body, 'plain'))

        session.sendmail(sender_email, receiver_email, message.as_string())
        session.quit()
        print(f"Email sent to {receiver_email}")

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
            print("Booking details with doctor and user info:", booking)
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        email_service = EmailService()

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        email_service.send_email(
            sender_email='your_email@gmail.com',  # Replace with your email
            sender_passwd='your_app_password',  # Replace with your app password
            receiver_email=user_email,
            subject=user_subject,
            body=user_body
        )

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        email_service.send_email(
            sender_email='doctorbackend9@gmail.com',  # Replace with your email
            sender_passwd='uprkkdjxtjladpf',  # Replace with your app password
            receiver_email=doctor_email,
            subject=doctor_subject,
            body=doctor_body
        )
    else:
        print("No recent bookings found.")

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))  # Explicitly print the createdAt field
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# {'_id': ObjectId('6658518e2fa08c7c59b2b96c'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), 'updatedAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), '__v': 0}
# createdAt: 2024-05-30 10:14:38.360000
# {'_id': ObjectId('667e50ba5679fc87a7798187'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), 'updatedAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), '__v': 0}
# createdAt: 2024-06-28 05:57:14.699000
# ...

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient
from bson import ObjectId

# Email service class
class EmailService:
    def __init__(self):
        pass

    import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

# Send email function
def send_email(subject, to_email, body):
    from_email = "doctorbackend9@gmail.com"  # Replace with your email
    from_password = "qadr huqm xcmu rscq"  # Replace with your email password

    # Setup the MIME
    message = MIMEMultipart()
    message['From'] = from_email
    message['To'] = to_email
    message['Subject'] = subject

    # Add body to email
    message.attach(MIMEText(body, 'plain'))

    # Send email
    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login(from_email, from_password)
            server.sendmail(from_email, to_email, message.as_string())
            print(f"Email sent to {to_email}")
    except Exception as e:
        print(f"Failed to send email to {to_email}: {e}")

# Testing the send_email function
send_email("Test Subject", "fazyamir@gmail.com", "This is a test email.")

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
            print("Booking details with doctor and user info:", booking)
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        email_service = EmailService()

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        email_service.send_email(
            sender_email='your_email@gmail.com',  # Replace with your email
            sender_passwd='your_app_password',  # Replace with your app password
            receiver_email=user_email,
            subject=user_subject,
            body=user_body
        )

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        email_service.send_email(
            sender_email='doctorbackend9@gmail.com',  # Replace with your email
            sender_passwd='uprk kdjx tjla dpf',  # Replace with your app password
            receiver_email=doctor_email,
            subject=doctor_subject,
            body=doctor_body
        )
    else:
        print("No recent bookings found.")

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))  # Explicitly print the createdAt field
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# Email sent to fazyamir@gmail.com
# MongoDB connection successful
# All bookings in the collection:
# {'_id': ObjectId('6658518e2fa08c7c59b2b96c'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), 'updatedAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), '__v': 0}
# createdAt: 2024-05-30 10:14:38.360000
# {'_id': ObjectId('667e50ba5679fc87a7798187'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), 'updatedAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), '__v': 0}
# createdAt: 2024-06-28 05:57:14.699000
# ...

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from pymongo import MongoClient
from bson import ObjectId

# Email service class
class EmailService:
    def __init__(self, from_email, from_password):
        self.from_email = from_email
        self.from_password = from_password

    def send_email(self, to_email, subject, body):
        # Setup the MIME
        message = MIMEMultipart()
        message['From'] = self.from_email
        message['To'] = to_email
        message['Subject'] = subject

        # Add body to email
        message.attach(MIMEText(body, 'plain'))

        # Send email
        try:
            with smtplib.SMTP('smtp.gmail.com', 587) as server:
                server.starttls()
                server.login(self.from_email, self.from_password)
                server.sendmail(self.from_email, to_email, message.as_string())
                print(f"Email sent to {to_email}")
        except Exception as e:
            print(f"Failed to send email to {to_email}: {e}")

# MongoDB connection
def get_mongo_client():
    try:
        client = MongoClient("mongodb+srv://muhammadrafay:doctorbackend@cluster0.gg9o2ef.mongodb.net/?retryWrites=true&w=majority")
        print("MongoDB connection successful")
        return client
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

# Fetch the most recent booking details along with user and doctor details
def get_most_recent_booking():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find().sort("createdAt", -1).limit(1)
        booking = None

        # Check if the cursor has any results
        for doc in cursor:
            booking = doc

        if booking:
            print("Booking found:", booking)
            doctor = db.doctors.find_one({"_id": ObjectId(booking['doctor'])})
            user = db.users.find_one({"_id": ObjectId(booking['user'])})
            booking['doctor_details'] = doctor
            booking['user_details'] = user
            print("Booking details with doctor and user info:", booking)
        else:
            print("No booking found")
        
        client.close()
        return booking
    except Exception as e:
        print(f"Error fetching booking details: {e}")
        return None

# Main function to handle booking and email notifications
def handle_booking_email():
    booking = get_most_recent_booking()
    
    if booking:
        user_email = booking['user_details']['email']
        doctor_email = booking['doctor_details']['email']
        booking_details = f"""
        Booking ID: {booking['_id']}
        Patient: {booking['user_details']['name']}
        Doctor: {booking['doctor_details']['name']}
        Ticket Price: {booking['ticketPrice']}
        Status: {booking['status']}
        Paid: {"Yes" if booking['isPaid'] else "No"}
        Date: {booking['createdAt']}
        """

        from_email = "doctorbackend9@gmail.com"  # Replace with your email
        from_password = "qadr huqm xcmu rscq"  # Replace with your app password
        email_service = EmailService(from_email, from_password)

        print("Sending email to user")
        # Email to user (patient)
        user_subject = "Your Appointment Booking Confirmation"
        user_body = f"Dear {booking['user_details']['name']},\n\nYour appointment has been confirmed. Here are the details:\n{booking_details}"
        email_service.send_email(user_email, user_subject, user_body)

        print("Sending email to doctor")
        # Email to doctor
        doctor_subject = "New Appointment Booking"
        doctor_body = f"Dear Dr. {booking['doctor_details']['name']},\n\nYou have a new appointment booking. Here are the details:\n{booking_details}"
        email_service.send_email(doctor_email, doctor_subject, doctor_body)
    else:
        print("No recent bookings found.")

# Print all bookings to debug
def print_all_bookings():
    client = get_mongo_client()
    if client is None:
        return None

    db = client.test  # Use the 'test' database
    
    try:
        cursor = db.bookings.find()
        print("All bookings in the collection:")
        for doc in cursor:
            print(doc)
            print("createdAt:", doc.get('createdAt'))  # Explicitly print the createdAt field
        client.close()
    except Exception as e:
        print(f"Error fetching all bookings: {e}")

# Example usage
if __name__ == "__main__":
    # Print all bookings to debug
    print_all_bookings()
    # Handle the most recent booking email
    handle_booking_email()
# Out:
# MongoDB connection successful
# All bookings in the collection:
# {'_id': ObjectId('6658518e2fa08c7c59b2b96c'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), 'updatedAt': datetime.datetime(2024, 5, 30, 10, 14, 38, 360000), '__v': 0}
# createdAt: 2024-05-30 10:14:38.360000
# {'_id': ObjectId('667e50ba5679fc87a7798187'), 'doctor': ObjectId('664e09aab6d53c2fb1d63372'), 'user': ObjectId('667e49c25679fc87a7798135'), 'ticketPrice': '2000', 'status': 'approved', 'isPaid': True, 'createdAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), 'updatedAt': datetime.datetime(2024, 6, 28, 5, 57, 14, 699000), '__v': 0}
# createdAt: 2024-06-28 05:57:14.699000
# ...
